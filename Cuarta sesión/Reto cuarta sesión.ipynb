# %% [markdown]
# **MÓDULO 4 - PLATAFORMAS DE VISUALIZACIÓN**
#
# ---
#
# **SESIÓN: Aplica en el trabajo**

# %% [markdown]
# NOMBRE: Amaury Félix Díaz

# %% [markdown]
# 1.	Genera una libreta en Google Colab para el reto, cuya estructura esté basada en los análisis solicitados.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2.	Descarga el archivo: Employees.csv y guarda, en un dataframe (`employees`), todos sus registros.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
employees = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data Science and AI/Cuarta sesión/employees.csv')
employees
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_23371      F  42.0                4             Married
# 1      EID_18000      M  24.0                3              Single
# 2       EID_3891      F  58.0                3             Married
# 3      EID_17492      F  26.0                3              Single
# 4      EID_22534      F  31.0                1             Married
# ...          ...    ...   ...              ...                 ...
# 6995   EID_16328      F  23.0                5             Married
# 6996    EID_8387      F  44.0                1             Married
# 6997    EID_8077      F  49.0                3              Single
# 6998   EID_19597      F  47.0                3             Married
# 6999    EID_1640      F  58.0                3             Married
#
#          Hometown                       Unit Decision_skill_possess  \
# 0        Franklin                         IT             Conceptual
# ...

# %% [markdown]
# 3.	Observa la estructura y contenido del dataframe con los atributos y métodos estudiados (`shape`, `columns`, `head()`, `dtypes`, `isna()`)

# %%
employees.shape
# Out:
# (7000, 17)

# %%
employees.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Education_Level',
#        'Relationship_Status', 'Hometown', 'Unit', 'Decision_skill_possess',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Compensation_and_Benefits',
#        'Work_Life_balance', 'Attrition_rate'],
#       dtype='object')

# %%
employees.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  growth_rate  Travel_Rate  Post_Level  Pay_Scale  \
# ...

# %%
employees.dtypes
# Out:
# Employee_ID                   object
# Gender                        object
# Age                          float64
# Education_Level                int64
# Relationship_Status           object
# Hometown                      object
# Unit                          object
# Decision_skill_possess        object
# Time_of_service              float64
# Time_since_promotion           int64
# growth_rate                    int64
# Travel_Rate                    int64
# Post_Level                     int64
# Pay_Scale                    float64
# Compensation_and_Benefits     object
# Work_Life_balance            float64
# Attrition_rate               float64
# dtype: object

# %%
employees.isna()
# Out:
#       Employee_ID  Gender    Age  Education_Level  Relationship_Status  \
# 0           False   False  False            False                False
# 1           False   False  False            False                False
# 2           False   False  False            False                False
# 3           False   False  False            False                False
# 4           False   False  False            False                False
# ...           ...     ...    ...              ...                  ...
# 6995        False   False  False            False                False
# 6996        False   False  False            False                False
# 6997        False   False  False            False                False
# 6998        False   False  False            False                False
# 6999        False   False  False            False                False
#
#       Hometown   Unit  Decision_skill_possess  Time_of_service  \
# ...

# %% [markdown]
# 4.	Calcula el % total de valores faltantes y elimina los registros que contengan `NaN`

# %%
# Con las funciones isna() y sum() obtenemos un total de los valores nulos y multiplicándolos por 100 y dividiéndolos entre el total de registros obtenemos un porcentaje
employees.isna().sum() * 100 / employees.shape[0]
# Out:
# Employee_ID                  0.000000
# Gender                       0.000000
# Age                          5.885714
# Education_Level              0.000000
# Relationship_Status          0.000000
# Hometown                     0.000000
# Unit                         0.000000
# Decision_skill_possess       0.000000
# Time_of_service              2.057143
# Time_since_promotion         0.000000
# growth_rate                  0.000000
# Travel_Rate                  0.000000
# Post_Level                   0.000000
# Pay_Scale                    0.128571
# Compensation_and_Benefits    0.000000
# Work_Life_balance            0.157143
# Attrition_rate               0.000000
# dtype: float64

# %%
# Usamos la función dropna() para eliminar los valores nulos
employees = employees.dropna()
employees
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_23371      F  42.0                4             Married
# 1      EID_18000      M  24.0                3              Single
# 2       EID_3891      F  58.0                3             Married
# 3      EID_17492      F  26.0                3              Single
# 4      EID_22534      F  31.0                1             Married
# ...          ...    ...   ...              ...                 ...
# 6995   EID_16328      F  23.0                5             Married
# 6996    EID_8387      F  44.0                1             Married
# 6997    EID_8077      F  49.0                3              Single
# 6998   EID_19597      F  47.0                3             Married
# 6999    EID_1640      F  58.0                3             Married
#
#          Hometown                       Unit Decision_skill_possess  \
# 0        Franklin                         IT             Conceptual
# ...

# %%
# Verificar si se realizó correctamente la eliminación de los valores nulos
employees.isna().sum() * 100 / employees.shape[0]
# Out:
# Employee_ID                  0.0
# Gender                       0.0
# Age                          0.0
# Education_Level              0.0
# Relationship_Status          0.0
# Hometown                     0.0
# Unit                         0.0
# Decision_skill_possess       0.0
# Time_of_service              0.0
# Time_since_promotion         0.0
# growth_rate                  0.0
# Travel_Rate                  0.0
# Post_Level                   0.0
# Pay_Scale                    0.0
# Compensation_and_Benefits    0.0
# Work_Life_balance            0.0
# Attrition_rate               0.0
# dtype: float64

# %% [markdown]
# 5.	Obtén la cantidad de valores únicos por columna, para responder:
# *  ¿Cuántos niveles educativos hay?
# *  ¿Cuántas ciudades participaron en el estudio?

# %%
employees.nunique()
# Out:
# Employee_ID                  6433
# Gender                          2
# Age                            47
# Education_Level                 5
# Relationship_Status             2
# Hometown                        5
# Unit                           12
# Decision_skill_possess          4
# Time_of_service                44
# Time_since_promotion            5
# growth_rate                    55
# Travel_Rate                     3
# Post_Level                      5
# Pay_Scale                      10
# Compensation_and_Benefits       5
# Work_Life_balance               5
# Attrition_rate               3184
# dtype: int64

# %%
# Utilizamos la función nunique() aplicada a las columnas de 'Education_Level' y de 'Hometown' para obtener las respuestas
print(f"El número de niveles educativos es de: {employees['Education_Level'].nunique()}")
print()
print(f"El número ciudades que participaron en el estudio es de: {employees['Hometown'].nunique()}")
# Out:
# El número de niveles educativos es de: 5
#
# El número ciudades que participaron en el estudio es de: 5

# %% [markdown]
# 6.	Realiza el conteo de valores por categoría (`value_counts()`) para las columnas de género y estado civil

# %%
# Aplicamos la función value_counts() para obtener un conteo por clasificación
employees[['Gender', 'Relationship_Status']].value_counts()
# Out:
# Gender  Relationship_Status
# F       Married                2462
# M       Married                1691
# F       Single                 1329
# M       Single                  951
# Name: count, dtype: int64

# %% [markdown]
# 7.	A través de la función `describe()` responde:
# *  ¿Cuál es el tiempo máximo de servicio?
# *  ¿Qué promedio de edad tienen los empleados encuestados?
# *  ¿Cuál es el valor del 1er cuartil en la escala de pago?

# %%
# Estadísticas descriptivas para los valores numéricos
stats = employees.describe().T
stats
# Out:
#                        count       mean        std   min      25%      50%  \
# Age                   6433.0  39.577025  13.619576  19.0  27.0000  37.0000
# Education_Level       6433.0   3.189492   1.063881   1.0   3.0000   3.0000
# Time_of_service       6433.0  13.396704  10.379039   0.0   5.0000  10.0000
# Time_since_promotion  6433.0   2.363439   1.149997   0.0   1.0000   2.0000
# growth_rate           6433.0  47.066532  15.743629  20.0  33.0000  47.0000
# Travel_Rate           6433.0   0.816104   0.647836   0.0   0.0000   1.0000
# Post_Level            6433.0   2.791544   1.162849   1.0   2.0000   3.0000
# Pay_Scale             6433.0   6.003731   2.053994   1.0   5.0000   6.0000
# Work_Life_balance     6433.0   2.389709   1.124412   1.0   1.0000   2.0000
# Attrition_rate        6433.0   0.189124   0.185625   0.0   0.0704   0.1426
#
#                           75%      max
# Age                   52.0000  65.0000
# Education_Level        4.0000   5.0000
# ...

# %%
# Estadísticas descriptivas para valores no numéricos
employees.describe(include = 'object')
# Out:
#        Employee_ID Gender Relationship_Status Hometown  Unit  \
# count         6433   6433                6433     6433  6433
# unique        6433      2                   2        5    12
# top       EID_1640      F             Married  Lebanon    IT
# freq             1   3791                4153     1908  1284
#
#        Decision_skill_possess Compensation_and_Benefits
# count                    6433                      6433
# unique                      4                         5
# top                Analytical                     type2
# freq                     1635                      3620

# %%
print(f"El tiempo máximo de servicio es de: {stats['max']['Time_of_service']}")
print(f"El promedio de edad de los empleados es de: {stats['mean']['Age']}")
print(f"El valor del 1er cuartil en la escala de pago es de: {stats['25%']['Pay_Scale']}")
# Out:
# El tiempo máximo de servicio es de: 43.0
# El promedio de edad de los empleados es de: 39.577024716306546
# El valor del 1er cuartil en la escala de pago es de: 5.0

# %% [markdown]
# 8.	Elabora en un histograma con las edades para identificar el rango más común.

# %%
# Elaborando un histograma con Pandas
employees['Age'].plot(kind = 'hist', bins = range(20, 65, 5))
plt.title('Distribución de edades')
plt.xlabel('Rangos de edad')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# De 20 a 35 es el rango de edad con más empleados.

# %% [markdown]
# 9.	Construye un gráfico de frecuencias (o conteo) para las unidades funcionales (`Unit`). ¿En qué unidad hay mayor número de empleados?

# %%
employees['Unit'].value_counts().plot(kind = 'bar')
plt.title('Frecuencia de empleados en unidades funcionales')
plt.xlabel('Unidades funcionales')
plt.ylabel('Frecuencia')
plt.show()

# %%
sns.countplot(x = employees['Unit'])
plt.title('Frecuencia de empleados en unidades funcionales')
plt.xlabel('Unidades funcionales')
plt.xticks(rotation = 90)
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Hay más empleados en la unidad de IT.

# %% [markdown]
# 10.	Realiza una agrupación por ciudad, con el promedio de todas las columnas y almacena el resultado en un nuevo dataframe (`employees_by_hometown`).

# %%
# Realizamos una agrupación por ciudad de las columnas que tiene únicamente valores numéricos en el dataframe
employees_by_hometown = employees.groupby('Hometown')[employees.select_dtypes(include = 'number').columns].mean()
employees_by_hometown
# Out:
#                    Age  Education_Level  Time_of_service  \
# Hometown
# Clinton      38.968992         3.160853        12.870155
# Franklin     40.029496         3.193525        13.730935
# Lebanon      40.024109         3.225367        13.825472
# Springfield  39.007500         3.157500        13.003125
# Washington   39.324828         3.181551        13.022571
#
#              Time_since_promotion  growth_rate  Travel_Rate  Post_Level  \
# Hometown
# Clinton                  2.286822    47.544574     0.868217    2.786822
# Franklin                 2.367626    47.001439     0.818705    2.774820
# Lebanon                  2.368973    46.539832     0.798742    2.790356
# Springfield              2.368125    47.037500     0.822500    2.803750
# Washington               2.378803    47.945044     0.808636    2.799804
#
#              Pay_Scale  Work_Life_balance  Attrition_rate
# Hometown
# Clinton       6.046512           2.443798        0.186583
# ...

# %% [markdown]
# 11.	Visualiza el dataframe obtenido en una única gráfica (usando Pandas: `employees_by_hometown.plot()`). Como no es legible por la diferencia de escalas en las columnas, sepáralas en subplots. ¿Qué ciudad tiene el mayor índice de deserción? Observa el resto de sus variables

# %%
# Utilizando el parámetro subplots de Pandas
employees_by_hometown.plot(subplots = True, layout = (5, 2), figsize = (15, 15))
plt.show()

# %% [markdown]
# Springfield tiene el mayor score en Attrition rate, lo que significa que tienden más a desertar de su empleo.

# %% [markdown]
# 12.	Utiliza el dataframe original (sin los NaN) para analizar el impacto del nivel educativo en la escala de pago. Para ello construye un box plot que considere estas dos variables.

# %%
employees.boxplot(column = 'Pay_Scale', by = 'Education_Level', figsize = (15, 10))
plt.title('Impacto del nivel educativo en la escala de pago')
plt.xlabel('Nivel educativo')
plt.ylabel('Escala de pago')
plt.show()

# %% [markdown]
# 13.	Elabora dos scatter plots (del dataframe original sin NaN) para determinar si hay correlación entre:
# *   Edad y Tasa de deserción
# *   Tiempo de servicio y Tasa de deserción

# %%
employees.plot(kind = 'scatter', x = 'Age', y = 'Attrition_rate')
plt.title('Edad vs Tasa de deserción')
plt.xlabel('Edad')
plt.ylabel('Tasa de deserción')
plt.show()

# %%
employees.plot(kind = 'scatter', x = 'Time_of_service', y = 'Attrition_rate')
plt.title('Tiempo de servicio vs Tasa de deserción')
plt.xlabel('Tiempo de servicio')
plt.ylabel('Tasa de deserción')
plt.show()

# %% [markdown]
# 14.	Crea un heatmap  (del dataframe original sin NaN) que muestre la correlación entre todos los pares de variables numéricas.

# %%
# Usando seaborn para crear un heatmap
sns.heatmap(employees.select_dtypes(include = 'number').corr(), annot = True, annot_kws = {'size': 7}, linewidth = 0.5)
plt.figure(figsize = (15, 15))
plt.show()
