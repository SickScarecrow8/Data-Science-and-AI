# %% [markdown]
# # **Módulo 2. Plataformas de Aplicación sobre Python**
# **Práctica 1 - Análisis de Tweets de la vacunación**
# ---

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Leer el archivo vaccination_tweets.csv y dejarlo en un dataframe

# %%
tweets = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data Science and AI/Segunda sesión/vaccination_tweets.csv")
tweets
# Out:
#                 id             user_name                   user_location  \
# 0     1.340000e+18            Rachel Roh       La Crescenta-Montrose, CA
# 1     1.340000e+18           Albert Fong               San Francisco, CA
# 2     1.340000e+18              eli🇱🇹🇪🇺👌                        Your Bed
# 3     1.340000e+18         Charles Adler          Vancouver, BC - Canada
# 4     1.340000e+18  Citizen News Channel                             NaN
# ...            ...                   ...                             ...
# 4275  1.350000e+18          Cate Cammack                             NaN
# 4276  1.350000e+18        SUR in English                   Malaga, Spain
# 4277  1.350000e+18       Melissa coleman                     Borehamwood
# 4278  1.350000e+18          The Insider🦉  J.Laurel St, Sn Miguel, Manila
# 4279  1.350000e+18         Dr Ai Lyn Tan                       Leeds, UK
#
#                                        user_description    user_created  \
# 0     Aggregator of Asian American news; scanning di...  08/04/09 17:52
# 1     Marketing dude, tech geek, heavy metal & '80s ...  21/09/09 15:27
# 2                                        heil, hydra 🖐☺  25/06/20 23:30
# 3     Hosting "CharlesAdlerTonight" Global News Radi...  10/09/08 11:28
# 4     Citizen News Channel bringing you an alternati...  23/04/20 17:58
# ...                                                 ...             ...
# 4275  Final year occupational therapy student at the...  22/11/20 18:41
# 4276  SUR in English, the English-language newspaper...  09/10/12 12:42
# 4277  I am a administrator with the vaccination team...  02/12/12 13:21
# 4278  #LoresAndApothegms𓅓 \nfrom the former summer h...  11/11/20 16:11
# 4279  Associate Professor. Rheumatologist. Research:...  13/12/12 15:38
#
#       user_followers  user_friends  user_favourites  user_verified  \
# 0                405          1692             3247          False
# 1                834           666              178          False
# 2                 10            88              155          False
# 3              49165          3933            21853           True
# 4                152           580             1473          False
# ...              ...           ...              ...            ...
# 4275              41           172               43          False
# 4276            5438           629              217          False
# 4277             788          1858             6698          False
# 4278              35           627               17          False
# 4279            5144           184            10062          False
#
#                 date                                               text  \
# 0      20/12/20 6:06  Same folks said daikon paste could treat a cyt...
# 1     13/12/20 16:27  While the world has been on the wrong side of ...
# 2     12/12/20 20:33  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3     12/12/20 20:23  Facts are immutable, Senator, even when you're...
# 4     12/12/20 20:17  Explain to me again why we need a vaccine @Bor...
# ...              ...                                                ...
# 4275  14/01/21 11:32  Just had my first dose of the #PfizerBioNTech ...
# 4276  14/01/21 10:40  #Andalucia to start vaccinating over 80s livin...
# 4277  14/01/21 10:37  First Pfizer covid 19 vaccine dose done ✅ very...
# 4278   14/01/21 9:36  A ‘healthy’ doctor died two weeks after gettin...
# 4279   14/01/21 8:43  Day 21 post #covid19 #vaccination\n\nMy 2nd ja...
#
#                                                hashtags               source  \
# 0                                    ['PfizerBioNTech']  Twitter for Android
# 1                                                   NaN      Twitter Web App
# 2     ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                                   NaN      Twitter Web App
# 4        ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
# ...                                                 ...                  ...
# 4275          ['PfizerBioNTech', 'Ihavebeenvaccinated']      Twitter Web App
# 4276                                      ['Andalucia']            TweetDeck
# 4277                 ['PfizerBioNTech', 'CovidVaccine']  Twitter for Android
# 4278                                        ['Vaccine']  Twitter for Android
# 4279                         ['covid19', 'vaccination']  Twitter for Android
#
#       retweets  favorites  is_retweet
# 0            0          0       False
# 1            1          1       False
# 2            0          0       False
# 3          446       2129       False
# 4            0          0       False
# ...        ...        ...         ...
# 4275         1          8       False
# 4276         0          2       False
# 4277         0          0       False
# 4278         0          0       False
# 4279         3          5       False
#
# [4280 rows x 16 columns]

# %% [markdown]
# Los 5 usuarios con más seguidores

# %%
tweets.nlargest(5, 'user_followers')
# Out:
#                 id  user_name   user_location  \
# 1121  1.340000e+18       CGTN  Beijing, China
# 2113  1.340000e+18   ABP News           India
# 1456  1.340000e+18  The Hindu  Chennai, India
# 1469  1.340000e+18  The Hindu  Chennai, India
# 912   1.340000e+18  The Hindu  Chennai, India
#
#                                        user_description    user_created  \
# 1121  CGTN is an international media organization. I...   24/01/13 3:18
# 2113           Follow for latest news alerts from India  11/05/09 12:25
# 1456         News feeds from India's National Newspaper   13/02/09 6:04
# 1469         News feeds from India's National Newspaper   13/02/09 6:04
# 912          News feeds from India's National Newspaper   13/02/09 6:04
#
#       user_followers  user_friends  user_favourites  user_verified  \
# 1121        13714928            69              159           True
# 2113        10741934            67              129           True
# 1456         6569222           212              153           True
# 1469         6569222           212              153           True
# 912          6565800           211              153           True
#
#                 date                                               text  \
# 1121   25/12/20 0:38  The #French National Authority for Health said...
# 2113   01/01/21 3:07  #WHO Grants 'Emergency Validation' For #Pfizer...
# 1456   22/12/20 7:40  The U.S. began administering vaccines a week a...
# 1469   22/12/20 4:45  The #EU finally gave the green light for the #...
# 912   18/12/20 11:30  “Our challenge now is to ensure that vaccines ...
#
#                                             hashtags           source  \
# 1121                           ['French', 'vaccine']  Twitter Web App
# 2113       ['WHO', 'PfizerBioNTech', 'CovidVaccine']  Twitter Web App
# 1456                              ['PfizerBioNTech']        TweetDeck
# 1469  ['EU', 'PfizerBioNTech', 'coronavirusvaccine']       SocialFlow
# 912                                              NaN        TweetDeck
#
#       retweets  favorites  is_retweet
# 1121        12         38       False
# 2113         1         28       False
# 1456         0         22       False
# 1469         3         54       False
# 912          3         10       False

# %% [markdown]
# La cantidad promedio de amigos que tienen los usuarios

# %%
tweets[['user_friends']].mean()
# Out:
# user_friends    1156.206075
# dtype: float64

# %% [markdown]
# La cantidad de usuarios por cada fuente de donde hicieron el tweet

# %%
tweets[['source', 'id']].groupby('source').count()
# Out:
#                                    id
# source
# 24liveblog                          4
# Blog2Social APP                     1
# Buffer                             36
# EastMojo                            1
# Echobox                             2
# Falcon Social Media Management      2
# GT_Backend                          2
# Hootsuite Inc.                     16
# IFTTT                               3
# Instagram                          24
# LinkedIn                            5
# Microsoft Power Platform            5
# News Users                          1
# Nonli                               6
# Paper.li                            1
# Publer                              1
# Sendible                            2
# SocialFlow                          5
# SocialNewsDesk                      1
# Socialbakers                        1
# Sprout Social                       1
# ThreadReaderApp                     1
# TweetCaster for Android             1
# TweetDeck                         240
# Tweetbot for Mac                    1
# Twitter Media Studio                2
# Twitter Media Studio - LiveCut      1
# Twitter Web App                  1271
# Twitter for Android               999
# Twitter for Mac                     3
# Twitter for iPad                  112
# Twitter for iPhone               1526
# UberSocial for Android              1
# WordPress.com                       1

# %% [markdown]
# El promedio de retweets, sin considerar a aquellos usuarios que no tienen retweetts

# %%
retweetsdf = tweets.loc[tweets['retweets'] > 0, ['user_name', 'retweets']]
retweetsdf['retweets'].mean()
# Out:
# 5.893939393939394

# %% [markdown]
# Los 5 primeros usuarios que tienen más de 100 favoritos

# %%
favorites = tweets.loc[tweets['favorites'] > 100, ['user_name', 'favorites']]
favorites.nlargest(5, 'favorites')
# Out:
#                              user_name  favorites
# 3715  Jamie (one jab down💉)Sherrington       2222
# 3                        Charles Adler       2129
# 183                        Anita Anand       1979
# 1561                       Ramesh Bala       1786
# 2826                        Chris Ship       1422
