# %% [markdown]
# # **Módulo 2. Plataformas de Aplicación sobre Python**
# ---

# %%
import numpy as np

# %% [markdown]
# **TEMA 1. Operaciones importantes con NumPy**

# %% [markdown]
# Se tiene un sistema de dos ecuaciones con dos incógnitas x1 y x2. Se desea encontrar los valores de dichas incógnitas para que satisfagan las ecuaciones que se muestran a continuación:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Donde A, B, C, D, E, F son datos que el usuario debe introducir y a partir de ellos se debe resolver el sistema de ecuaciones.

# %% [markdown]
# 1. Pida los valores de A, B, C, D, E y F

# %%
A = float(input("Ingrese el valor de A: "))
B = float(input("Ingrese el valor de B: "))
C = float(input("Ingrese el valor de C: "))
D = float(input("Ingrese el valor de D: "))
E = float(input("Ingrese el valor de E: "))
F = float(input("Ingrese el valor de F: "))
# Out:
# Ingrese el valor de A: 2
# Ingrese el valor de B: 3
# Ingrese el valor de C: 18
# Ingrese el valor de D: 1
# Ingrese el valor de E: -1
# Ingrese el valor de F: 3

# %% [markdown]
# 2. Crea la matriz A de la forma ![image.png](data:image/png;base64,...)

# %%
matA = np.array([A, B, D, E]).reshape(2, 2)
print(matA)
# Out:
# [[ 2.  3.]
#  [ 1. -1.]]

# %% [markdown]
# 3. Crea la matriz B de la forma ![image.png](data:image/png;base64,...)

# %%
matB = np.array([C, F]).reshape(2, 1)
print(matB)
# Out:
# [[18.]
#  [ 3.]]

# %% [markdown]
# 4. Calcula la matriz inversa de A

# %%
inversaA = np.linalg.inv(matA)
print(inversaA)
# Out:
# [[ 0.2  0.6]
#  [ 0.2 -0.4]]

# %% [markdown]
# 5. Multiplique la inversa de A por B

# %%
producto = inversaA @ matB
print(producto)
# Out:
# [[5.4]
#  [2.4]]

# %% [markdown]
# 5. Analice los resultados

# %%
print(f"El valor de x es {producto[0]} y el valor de y es {producto[1]}.")
# Out:
# El valor de x es [5.4] y el valor de y es [2.4].
