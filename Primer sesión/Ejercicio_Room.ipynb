# %% [markdown]
# # Ejercicios Python

# %%
txt = input('Escribe una oración: ')
print(txt)

print()

print(len(txt))

print()

e_txt = txt.count('e')
print(e_txt)

print()

print(txt.title())

print()

print(txt.split(" "))

print()

replaces_txt = txt.replace('s','$')
print(replaces_txt)
# Out:
# Escribe una oración: Soy cientifico de datos
# Soy cientifico de datos
#
# 23
#
# 2
#
# Soy Cientifico De Datos
#
# ['Soy', 'cientifico', 'de', 'datos']
#
# Soy cientifico de dato$

# %%
txt2= input("Dame otro texto: ")
txt2.count("el")
print(txt2)
print(txt2.split(" "))
print (len(txt2.split(" ")))
dic={"Integrantes": "Fernando", "Edad": 20, "Ciudad": "Monterrey"}
print(dic)
print(len.dic())
# Out:
# Dame otro texto: Hola
# Hola
# ['Hola']
# 1
# {'Integrantes': 'Fernando', 'Edad': 20, 'Ciudad': 'Monterrey'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-757f1234bca7> in <cell line: 0>()
#       6 dic={"Integrantes": "Fernando", "Edad": 20, "Ciudad": "Monterrey"}
#       7 print(dic)
# ----> 8 print(len.dic())
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'dic'

# %%
num1 = int(input("Dame nunmero 1: "))
num2 = int(input("Dame nunmero 2: "))
num3 = int(input("Dame nunmero 3: "))

if num1 > num2 and num1 > num3:
    print("Numero 1 es el mayor")
elif num2 > num3 and num2 > num1:
    print("Numero 2 es el mayor")
elif num3 > num2 and num3 > num1:
    print("Numero 3 es el mayor")
else:
    print("Los 3 son iguales")
# Out:
# Dame nunmero 1: 5
# Dame nunmero 2: 5
# Dame nunmero 3: 5
# Los 3 son iguales

# %%
temp= float(input("Ingrese su temperatura : "))
if temp>=36.5 and temp<=37:
    print("Temperatura Normal")
elif temp>37 and temp<38:
      print("Temperatura Febricula")
elif temp>38:
      print("Temperatura Fiebre")
else:
     print("Temperatura incorrecta")
# Out:
# Ingrese su temperatura : 40
# Temperatura Fiebre

# %%
lst = [1, 2, 3, 4, 5, 6, 7, 8, 9]

sum = 0
avg = 0

for i in lst:
    print(i)

for i in lst:
    sum = sum + i
print(sum)

for i in lst:
    avg = avg + i
avg = avg / len(lst)
print(avg)

txt = input("Escribe un texto: ")
contador_vocal = 0
contador_consonante = 0
for vocal in txt:
    if vocal in "aeiou":
        contador_vocal += 1
    else:
        contador_consonante += 1
print(f"El número de vocales es de: {contador_vocal}.")
print(f"El número de vocales es de: {contador_consonante}.")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 45
# 5.0
# Escribe un texto: aaaaff
# El número de vocales es de: 4.
# El número de vocales es de: 2.
