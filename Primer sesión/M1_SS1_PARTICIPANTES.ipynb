# %% [markdown]
# **MÓDULO 1 - FUNDAMENTOS DE PYTHON - SS1**
#
# ---

# %% [markdown]
# # **TEMA 1. Estructuras de Datos**

# %% [markdown]
# ##1.1 Tipos de datos

# %%
print("Hello World")
print('My Name is', 'Rosa', '!')
# Out:
# Hello World
# My Name is Rosa !

# %%
# Booleanos
married = False
print('Casado(a):', married)
print(type(married))
# Out:
# Casado(a): False
# <class 'bool'>

# %%
# Enteros
a = 2
print(a)
print(type(a))

b = 0b10101
print(b)
c = 0o127
print(c)
d = 0xFF
print(d)
# Out:
# 2
# <class 'int'>
# 21
# 87
# 255

# %%
# Flotantes
PI = 3.1416
print(PI)
print(type(PI))
# Out:
# 3.1416
# <class 'float'>

# %%
# Complejos
f = complex(3, 2)
print(f)
print(type(f))
print(f.real, '+', f.imag, 'i')
# Out:
# (3+2j)
# <class 'complex'>
# 3.0 + 2.0 i

# %%
# Strings
text = "Las cadenas de caracteres o strings contienen texto."
print(text)
print(type(text))

print()

title = text.title()
print(title)
cap = text.upper()
print(cap)
low = text.lower()
print(low)

print()

print(text)
# Out:
# Las cadenas de caracteres o strings contienen texto.
# <class 'str'>
#
# Las Cadenas De Caracteres O Strings Contienen Texto.
# LAS CADENAS DE CARACTERES O STRINGS CONTIENEN TEXTO.
# las cadenas de caracteres o strings contienen texto.
#
# Las cadenas de caracteres o strings contienen texto.

# %%
# Pedir un texto al usuario
txt = input('Dame una oración: ')
print(txt)
# Out:
# Dame una oración: こんにちは 🌤️
# こんにちは 🌤️

# %% [markdown]
# ##1.2 Estructuras de datos

# %%
# Listas
lst = ['uno', 'dos', 'tres', 'cuatro', 'cinco']
print(lst)
print('La lista contiene', len(lst), 'elementos')
# Out:
# ['uno', 'dos', 'tres', 'cuatro', 'cinco']
# La lista contiene 5 elementos

# %%
# recuperar el elemento en una posición
print(lst[2])
# recuperar el elemento en una posición usando números negativos
print(lst[-2])
# recuperar la lista de elementos en un rango
print(lst[2:4])
print(lst[1:])
print(lst[:3])
# Out:
# tres
# cuatro
# ['tres', 'cuatro']
# ['dos', 'tres', 'cuatro', 'cinco']
# ['uno', 'dos', 'tres']

# %%
#imprimir la posición en la que encuentra el elemento
print(lst.index('cinco'))
# agregar un elemento al final de la lista
lst.append('seis')
# agregar un elemento en alguna posición de la lista
lst.insert(0, 'cero')
print(lst)
# Out:
# 4
# ['cero', 'uno', 'dos', 'tres', 'cuatro', 'cinco', 'seis']

# %%
# Diccionarios
dict1 = {'raza':'pastor alemán', 'peso':45, 'nombre':'Linus', 'color':'negro'}
print(dict1)
print(dict1['raza'])
print(dict1['peso'])
# Out:
# {'raza': 'pastor alemán', 'peso': 45, 'nombre': 'Linus', 'color': 'negro'}
# pastor alemán
# 45

# %%
dict2 = {'marca': ['bonafont', 'ciel', 'epura'], 'precio':10, 'contenido':500}
print(dict2)
print(dict2['marca'])
# Out:
# {'marca': ['bonafont', 'ciel', 'epura'], 'precio': 10, 'contenido': 500}
# ['bonafont', 'ciel', 'epura']

# %%
# agregar un par clave:valor al diccionario
dict2['presentación'] = 'botella 💧'
dict2['precio'] = 20
print(dict2)
# Out:
# {'marca': ['bonafont', 'ciel', 'epura'], 'precio': 20, 'contenido': 500, 'presentación': 'botella 💧'}

# %% [markdown]
# # **TEMA 2. Estatutos condicionales**

# %% [markdown]
# ##2.1 If

# %%
# Ejemplo de estatuto if
n = 5

if n == 0:
    print('El número es cero')
    print('Línea dentro del if')

print('Primera línea después del if')
# Out:
# Primera línea después del if

# %%
# Ejemplo de estatuto if
temperatura = 35

if temperatura >= 35:
    print("Es demasiado caliente para usar concreto.")

print('Primera línea después del if')
# Out:
# Es demasiado caliente para usar concreto.
# Primera línea después del if

# %%
# Pedir un número entero al usuario
num = int(input('Dame un número entero: '))
print(num)

nombre = input("Dame tu nombre: ")
print(nombre)

# Pedir un número con decimales al usuario
num2 = float(input('Dame un número con decimales: '))
print(num2)
# Out:
# Dame un número entero: 2
# 2
# Dame tu nombre: Rosa
# Rosa
# Dame un número con decimales: 4.5
# 4.5

# %% [markdown]
# ##2.2 Elif - Else

# %%
# Estatuto condicional if-else
edad = 2

if edad >= 18:
    print('Mayor de edad')
else:
    print('Menor de edad')
# Out:
# Menor de edad

# %%
# Estatuto condicional if-elif-else
temp = 45

if temp < 10:
    print('Frío')
elif temp < 20:
    print('Templado')
elif temp < 30:
    print('Un poco caluroso')
else:
    print('Muy caluroso')
# Out:
# Muy caluroso

# %%
# Estatuto condicional if
text = 'entrada'
numero = 22

# operadores lógicos: and, or, not
if text == 'entrada' and numero >= 18:
    print('puedes pasar')

if text == 'entrada':
    if numero >= 18:
        print('puedes pasar')
# Out:
# puedes pasar
# puedes pasar

# %% [markdown]
# # **TEMA 3. Estatutos de repetición**

# %% [markdown]
# ##3.1 While

# %%
# Estatuto while simple
num = int(input('Dame un entero positivo: '))
i = 0

while i <= num:
    print(i)
    i = i + 1   # i += 1

print('Primera línea fuera del while')
# Out:
# Dame un entero positivo: 4
# 0
# 1
# 2
# 3
# 4
# Primera línea fuera del while

# %%
# Estatuto break
calificacion = 0
promedio = 0
i = 0
while i < 10:
    calificacion_txt = input('Dame una calificación o un número negativo o mayor a 10 para terminar')
    calificacion = float(calificacion_txt)
    print(calificacion)
    if calificacion < 0 or calificacion > 10:
        break
    promedio = promedio + calificacion
    i = i + 1

print('Primera línea fuera del while')
promedio = promedio / i
print('El promedio es:', promedio)

# %%
# Estatuto continue
i = 0
promedio = 0
while i < 5:
    grade_txt = input('Dame una calificación o un número negativo para un NP')
    grade = float(grade_txt)
    print(grade)
    if grade < 0:
        continue
    promedio = promedio + grade
    i = i + 1

print('Primera línea fuera del while')
promedio = promedio / i
print('El promedio es:', promedio)

# %% [markdown]
# ##3.2 For

# %%
# Estatuto for iterando sobre una cadena de caracteres
txt = input('Dame un texto: ')

for letra in txt:
    print(letra)
# Out:
# Dame un texto: Octavio
# O
# c
# t
# a
# v
# i
# o

# %%
# Estatuto for iterando sobre una cadena de caracteres
# Contar caracteres
txt = input('Dame un texto: ')
i = 0
for caracter in txt:
    print(caracter)
    i = i + 1
print('Número de caracteres:', i)
# Out:
# Dame un texto: Roberto
# R
# o
# b
# e
# r
# t
# o
# Número de caracteres: 7

# %%
# Estatuto for iterando sobre una lista
lst = [10, 74, 23, 80, 9, 30]
avg = 0
for num in lst:
    print(num)
    avg = avg + num   # avg += num
avg = avg / len(lst)

print(f'Número de elementos: {len(lst)}')
print(f'Promedio: \033[1;34m{avg:.2f}\033[0m')
# Out:
# 10
# 74
# 23
# 80
# 9
# 30
# Número de elementos: 6
# Promedio: 37.67

# %%
# Ejemplo de un ciclo for con rangos
# un solo argumento range(limite)
for n in range(5):
    print(n, end=" ")
# Out:
# 0 1 2 3 4

# %%
# dos argumentos range(inicio, limite)
for n in range(2, 7):
    print(n, end=" ")
# Out:
# 2 3 4 5 6

# %%
# tres argumentos range(inicio, limite, incremento)
for n in range(0, 10, 2):
    print(n, end=" ")
# Out:
# 0 2 4 6 8

# %%
for n in range(1,11):
    print("6 x", n, "=", (6 * n))
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %% [markdown]
# # **TEMA 4. Definición de Funciones**

# %% [markdown]
# ##4.1 Estructura de una función

# %%
# Definición de una función simple
def greet():
    print("Hello!")

greet()
# Out:
# Hello!

# %%
# Definición de una función con un parámetro
def greet(name):
    print('Hello', name)

greet('Juan Carlos')
greet('Patricia')
# Out:
# Hello Juan Carlos
# Hello Patricia

# %%
# Definición de una función que tiene un parámetro
# y un valor por defecto para el mismo
def greet(name = 'World'):
  print('Hello', name)

greet('Brenda')
greet()
# Out:
# Hello Brenda
# Hello World

# %%
# Definición de una función que recibe dos parámetros
def add(a, b):
    return a + b

x = add(2, 5)
print("Addition: ", x)
print("Addition: ", add(1.2, 7.5))
print("Addition: ", add(True, True))
print("Addition: ", add("a", "b"))
print("Addition: ", add(-1, 8))
# Out:
# Addition:  7
# Addition:  8.7
# Addition:  2
# Addition:  ab
# Addition:  7

# %%
def greet(times = 3):
    print("Hello " * times)

greet()
greet(5)
greet(8)
# Out:
# Hello Hello Hello
# Hello Hello Hello Hello Hello
# Hello Hello Hello Hello Hello Hello Hello Hello

# %% [markdown]
# ##4.2 Llamando a una función

# %%
# Llamada a una función con un parámetro
def greet(name):
  print('Hello', name)

greet('Rosa')
# Out:
# Hello Rosa

# %%
# Definición de la función
def factorial(n):
    fact = 1
    for x in range(1, n + 1):
        fact = fact * x
    return fact

# La función combinatoria calcula el número de posibles
# combinaciones al seleccionar un número m de elementos
# de un conjunto de n elementos
def combinatory(n, m):
    return factorial(n) / (factorial(m) * factorial(n-m))

# Llamada a la función
print(combinatory(6, 2))
print(combinatory(5, 3))
# Out:
# 15.0
# 10.0

# %%
# Definición de una función para calcular el área de un triángulo

def triangle_area(b, h):
    return b * h / 2

area = triangle_area(2.0, 5.0)
print('Área:', area)
# Out:
# Área: 5.0

# %% [markdown]
# # **TEMA 5. Manejo de Archivos de Texto**

# %% [markdown]
# Antes de comenzar revisar que el archivo prueba.txt se encuentra en el directorio de archivos del lado derecho en la ruta /content/sample_data
#
# En caso contrario, crear el archivo en su computadora y cargarlo en este directorio.

# %% [markdown]
# ## TEMA 5.1 Leer un archivo de texto

# %% [markdown]
# ***file_handler***

# %%
# Leer un archivo de texto con un file_handler
file_handler = open('/content/planets.csv')
for line in file_handler:
    print(line)
file_handler.close()
# Out:
# name,rotation_period,orbital_period,diameter,climate,gravity,terrain,surface_water,population
#
# Alderaan,24,364,12500,temperate,1 standard,"grasslands, mountains",40,2000000000
#
# Yavin IV,24,4818,10200,"temperate, tropical",1 standard,"jungle, rainforests",8,1000
#
# Hoth,23,549,7200,frozen,1.1 standard,"tundra, ice caves, mountain ranges",100,NA
#
# Dagobah,23,341,8900,murky,N/A,"swamp, jungles",8,NA
#
# Bespin,12,5110,118000,temperate,"1.5 (surface), 1 standard (Cloud City)",gas giant,0,6000000
#
# Endor,18,402,4900,temperate,0.85 standard,"forests, mountains, lakes",8,30000000
#
# Naboo,26,312,12120,temperate,1 standard,"grassy hills, swamps, forests, mountains",12,4500000000
#
# Coruscant,24,368,12240,temperate,1 standard,"cityscape, mountains",NA,1000000000000
#
# Kamino,27,463,19720,temperate,1 standard,ocean,100,1000000000
#
# Geonosis,30,256,11370,"temperate, arid",0.9 standard,"rock, desert, mountain, barren",5,100000000000
#
# ...

# %% [markdown]
# ***Solo lectura***

# %%
# Abrir un archivo de texto solo para lectura
file_handler = open('/content/sample_data/prueba.txt', 'r')
for line in file_handler:
  print(line)
file_handler.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-552571e94269> in <module>
#       1 # Abrir un archivo de texto solo para lectura
# ----> 2 file_handler = open('/content/sample_data/prueba.txt', 'r')
#       3 for line in file_handler:
#       4   print(line)
#       5 file_handler.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sample_data/prueba.txt'

# %% [markdown]
# ***Archivos vacíos: os stat y st_size***

# %%
import os

# Revisar si un archivo está vacío
def file_is_not_empty(name):
  return os.stat(name).st_size > 0

file_name = '/content/sample_data/prueba.txt'

if file_is_not_empty(file_name):
  file_handler = open(file_name)
  for line in file_handler:
    print(line)
  file_handler.close()
else:
  print('The file is empty')

# %%
# Contar el número de renglones de un archivo
file_handler = open('/content/sample_data/prueba.txt', 'r')
count = 0
for line in file_handler:
    count = count + 1
print('Número total de líneas:', count)
file_handler.close()

# %% [markdown]
# ## TEMA 5.2 Escribir en un archivo de texto

# %%
# La opción escribir (write), abre el archivo
# borra el contenido y agrega el nuevo texto
# Si el archivo no existe, lo crea
file_handler = open('/content/sample_data/prueba2.txt', 'w')
file_handler.write('Única línea en el archivo')
file_handler.close()

# %%
# La opción añadir (append), abre el archivo
# y agrega el texto al final
# Si el archivo no existe, lo crea
file_handler = open('/content/sample_data/prueba2.txt', 'a')
file_handler.write('Una línea más al final del archivo')
file_handler.close()

# %% [markdown]
# ***Listado recursivo de archivos***

# %% [markdown]
# ***Paquete glob***

# %%
import glob

# Obtener todos los archivos con una misma extensión
# dentro de un directorio
path = '/content/sample_data'
files = glob.glob(path + '/*.txt')
print(files)

# %% [markdown]
# ***Recursivamente***

# %%
import glob

# Obtener todos los archivos con una misma extensión
# dentro de un directorio de forma recursiva
path = '/content/sample_data'
files = glob.glob(path + '/**/*.txt', recursive=True)
print(files)

# %% [markdown]
# ***Iterador***

# %%
import glob

# Obtener todos los archivos con una misma extensión
# dentro de un directorio y guardarlos en un iterador
path = '/content/sample_data'
files = glob.iglob(path + '/*.txt')
for file in files:
  print(file)
